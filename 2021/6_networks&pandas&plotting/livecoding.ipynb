# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %% [markdown]
# See the pandas types

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# See the column labels of the dataframe

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %% [markdown]
# Access the sepal.length column

# %%
df["sepal.length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %% [markdown]
# One way of saving the variables we want to plot

# %%
x = df["sepal.length"]
y = df["sepal.width"]
x2 = df["petal.length"]
y2 = df["petal.width"]

# %% [markdown]
# Way of using integers to access the columns

# %%
df[df.columns[3]]
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal.width, Length: 150, dtype: float64

# %% [markdown]
# Get the unique values of a column

# %%
df["variety"].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %% [markdown]
# Pandas mapping function to assign a number to each flower variety

# %%
color = {'Setosa': 0,
         'Versicolor':1,
         'Virginica':2}

df["color"]= df["variety"].map(color)

# %% [markdown]
# Loop through all possible combinations of scatter plots and use histogram for diagonal.

# %%
fig, axes = plt.subplots(figsize = (16,12),ncols = 4, nrows = 4)
print(axes.shape)

for i, row in enumerate(axes):
    for j, col in enumerate(row):
        if i == j:
            col.hist(df.iloc[:,i])
            col.set_xlabel(df.columns[i])
        else:
            col.scatter(df.iloc[:,i],df.iloc[:,j], c=df["color"])
            col.set_xlabel(df.columns[i])
            col.set_ylabel(df.columns[j])
# Out:
# (4, 4)
